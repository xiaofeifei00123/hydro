# %%
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import baobao

# %%
flnm = '/home/fengx20/project/hydro/test3/RUN/route_01/DOMAIN/back2/Route_Link.nc'
ds = xr.open_dataset(flnm)
ds
# Out:
# <xarray.Dataset>
# Dimensions:            (feature_id: 175717)
# Coordinates:
#     lon                (feature_id) float32 ...
#     lat                (feature_id) float32 ...
# Dimensions without coordinates: feature_id
# Data variables: (12/20)
#     link               (feature_id) int32 ...
#     from               (feature_id) int32 ...
#     to                 (feature_id) int32 ...
#     alt                (feature_id) float32 ...
#     order              (feature_id) int32 ...
#     Qi                 (feature_id) float32 ...
#     ...                 ...
#     x                  (feature_id) float32 ...
#     y                  (feature_id) float32 ...
#     Kchan              (feature_id) int16 ...
#     gages              (feature_id) |S15 ...
#     NHDWaterbodyComID  (feature_id) int32 ...
#     crs                |S1 ...
# Attributes:
#     Conventions:  CF-1.5
#     featureType:  timeSeries
#     history:      Created Thu Dec 22 20:03:56 2022
